# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import os
os.chdir('V:\Datafiles')

# %%
df=pd.read_csv('gdp.csv' , parse_dates=True)

# %%
df
# Out:
#                     Items  Description Duration  Andhra Pradesh   \
# 0   GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1   GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2   GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3   GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4   GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5   GSDP - CURRENT PRICES (` in Crore)  2016-17        699307.00
# 6        (% Growth over previous year)  2012-13             8.43
# 7        (% Growth over previous year)  2013-14            12.85
# 8        (% Growth over previous year)  2014-15            13.40
# 9        (% Growth over previous year)  2015-16            15.85
# 10       (% Growth over previous year)  2016-17            14.65
#
#     Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa  \
# 0            11063.00  143175.00  247144.00     158074.00  42367.00
# ...

# %%
df.columns
# Out:
# Index(['Items  Description', 'Duration', 'Andhra Pradesh ',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal1', 'Andaman & Nicobar Islands',
#        'Chandigarh', 'Delhi', 'Puducherry', 'All_India GDP'],
#       dtype='object')

# %%
df.pivot_table(index=['Items  Description','Duration'])
# Out:
#                                              All_India GDP  \
# Items  Description                 Duration
# (% Growth over previous year)      2012-13           13.86
#                                    2013-14           12.97
#                                    2014-15           10.65
#                                    2015-16            9.99
# GSDP - CURRENT PRICES (` in Crore) 2011-12      8736039.00
#                                    2012-13      9946636.00
#                                    2013-14     11236635.00
#                                    2014-15     12433749.00
#                                    2015-16     13675331.00
#
#                                              Andaman & Nicobar Islands  \
# Items  Description                 Duration
# (% Growth over previous year)      2012-13                       11.13
#                                    2013-14                       16.68
# ...

# %%
df
# Out:
#                     Items  Description Duration  Andhra Pradesh   \
# 0   GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1   GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2   GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3   GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4   GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5   GSDP - CURRENT PRICES (` in Crore)  2016-17        699307.00
# 6        (% Growth over previous year)  2012-13             8.43
# 7        (% Growth over previous year)  2013-14            12.85
# 8        (% Growth over previous year)  2014-15            13.40
# 9        (% Growth over previous year)  2015-16            15.85
# 10       (% Growth over previous year)  2016-17            14.65
#
#     Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa  \
# 0            11063.00  143175.00  247144.00     158074.00  42367.00
# ...

# %%
df.drop([5,10],inplace=True)

# %%
df
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 0 to 9
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Items  Description         9 non-null      object
#  1   Duration                   9 non-null      object
#  2   Andhra Pradesh             9 non-null      float64
#  3   Arunachal Pradesh          9 non-null      float64
#  4   Assam                      9 non-null      float64
#  5   Bihar                      9 non-null      float64
#  6   Chhattisgarh               9 non-null      float64
#  7   Goa                        9 non-null      float64
#  8   Gujarat                    9 non-null      float64
#  9   Haryana                    9 non-null      float64
#  10  Himachal Pradesh           7 non-null      float64
#  11  Jammu & Kashmir            9 non-null      float64
#  12  Jharkhand                  9 non-null      float64
# ...

# %%
column_att=list(df.columns)

# %%
df.pivot_table(index=['Items  Description','Duration'])
# Out:
#                                              All_India GDP  \
# Items  Description                 Duration
# (% Growth over previous year)      2012-13           13.86
#                                    2013-14           12.97
#                                    2014-15           10.65
#                                    2015-16            9.99
# GSDP - CURRENT PRICES (` in Crore) 2011-12      8736039.00
#                                    2012-13      9946636.00
#                                    2013-14     11236635.00
#                                    2014-15     12433749.00
#                                    2015-16     13675331.00
#
#                                              Andaman & Nicobar Islands  \
# Items  Description                 Duration
# (% Growth over previous year)      2012-13                       11.13
#                                    2013-14                       16.68
# ...

# %%
df
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
del(column_att[0])

# %%
states=column_att

# %%
state_mean={}
for column in df:
    if column in states:
        mean=df[df['Items  Description']=='(% Growth over previous year)'][column].mean()
        state_mean[column]=mean
state_mean['Items  Description']='Avg_growth_rate'
df=df.append(state_mean,ignore_index=True)

# %%
df
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12      379402.0000
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13      411404.0000
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14      464272.0000
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15      526468.0000
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16      609934.0000
# 5       (% Growth over previous year)  2012-13           8.4300
# 6       (% Growth over previous year)  2013-14          12.8500
# 7       (% Growth over previous year)  2014-15          13.4000
# 8       (% Growth over previous year)  2015-16          15.8500
# 9                     Avg_growth_rate      NaN          12.6325
#
#    Arunachal Pradesh        Assam       Bihar  Chhattisgarh       Goa  \
# 0         11063.0000  143175.0000  247144.000   158074.0000  42367.00
# 1         12547.0000  156864.0000  282368.000   177511.0000  38120.00
# ...

# %%
df1=df.iloc[[8,4,9]]

# %%
df1
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 8       (% Growth over previous year)  2015-16          15.8500
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16      609934.0000
# 9                     Avg_growth_rate      NaN          12.6325
#
#    Arunachal Pradesh        Assam       Bihar  Chhattisgarh       Goa  \
# 8            12.0700      13.1900      10.590       10.9800     10.75
# 4         18784.0000  224234.0000  413503.000   260776.0000  45002.00
# 9            14.1625      11.8775      13.765       13.3525      2.02
#
#        Gujarat      Haryana  ...    Telangana    Tripura  Uttar Pradesh  \
# 8      11.0900      10.9100  ...      12.6100        NaN   1.058000e+01
# 4  994316.0000  485184.0000  ...  575631.0000        NaN   1.153795e+06
# 9      12.7675      13.0425  ...      12.4975  15.613333   1.236750e+01
#
#    Uttarakhand  West Bengal1  Andaman & Nicobar Islands  Chandigarh  \
# ...

# %%
df1=df1.T

# %%
df1.columns=df1.iloc[0]

# %%
df1=df1[1:]

# %%
df1
# Out:
# Items  Description        (% Growth over previous year)  \
# Andhra Pradesh                                    15.85
# Arunachal Pradesh                                 12.07
# Assam                                             13.19
# Bihar                                             10.59
# Chhattisgarh                                      10.98
# Goa                                               10.75
# Gujarat                                           11.09
# Haryana                                           10.91
# Himachal Pradesh                                    NaN
# Jammu & Kashmir                                   17.91
# Jharkhand                                         11.44
# Karnataka                                         11.42
# Kerala                                            11.85
# Madhya Pradesh                                    12.86
# Maharashtra                                         NaN
# Manipur                                             NaN
# ...

# %%
sns.catplot(x='Avg_growth_rate' ,y=df1.index, data=df1,kind='bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-ec1493124311> in <module>
# ----> 1 sns.catplot(x='Avg_growth_rate' ,y=df1.index, data=df1,kind='bar')
#       2 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3760
#    3761     # Draw the plot onto the facets
# -> 3762     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3763
#    3764     # Special case axis labels for a count type plot
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     829
#     830         # Finalize the annotations and layout
# ...

# %%
df1['GSDP - CURRENT PRICES (` in Crore)'].sort_values().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1.shape
# Out:
# (34, 3)

# %%
df1=df1[:33]

# %%
df1
# Out:
# Items  Description        (% Growth over previous year)  \
# Andhra Pradesh                                    15.85
# Arunachal Pradesh                                 12.07
# Assam                                             13.19
# Bihar                                             10.59
# Chhattisgarh                                      10.98
# Goa                                               10.75
# Gujarat                                           11.09
# Haryana                                           10.91
# Himachal Pradesh                                    NaN
# Jammu & Kashmir                                   17.91
# Jharkhand                                         11.44
# Karnataka                                         11.42
# Kerala                                            11.85
# Madhya Pradesh                                    12.86
# Maharashtra                                         NaN
# Manipur                                             NaN
# ...

# %%
df1['GSDP - CURRENT PRICES (` in Crore)'].sort_values().plot.bar()
# Out:
# <AxesSubplot:>
